# %%
import churninganalyzer as ca
import numpy as np
import pandas as pd
df=pd.read_csv('synthetic_customer_attrition_data.csv')
analyzer = ca.CustomerChurnAnalyzer(df)
analyzer.main()
# Out:
# The number of rows and columns in the dataset is: (10000, 21)
# The top five datapoints of the dataset is:
#    CLIENTNUM Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  CID-00001       Existing            49      M                0
# 1  CID-00002       Attrited            53      M                4
# 2  CID-00003       Existing            67      F                3
# 3  CID-00004       Existing            54      M                0
# 4  CID-00005       Existing            65      F                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0         Unknown         Single         Unknown          Gold
# 1         Unknown        Unknown         $120K +          Blue
# 2        Graduate        Unknown     $40K - $60K          Blue
# 3        Graduate        Married    $80K - $120K          Blue
# 4       Doctorate        Married    $80K - $120K          Blue
#
#    Months_on_Book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...
